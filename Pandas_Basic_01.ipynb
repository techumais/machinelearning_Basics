# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Dell/Desktop/DataScince/Pandas/DataSets/iris.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    variety
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1 = pd.read_excel("C:/Users/Dell/Desktop/DataScince/Pandas/DataSets/iris.xls")
df1
# Out:
#      sepal length  sepal width  petal length  petal width            iris  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
#      Unnamed: 5  Unnamed: 6 sepal length.1  Unnamed: 8
# ...

# %%
df2 = pd.read_csv("C:/Users/Dell/Desktop/DataScince/Pandas/DataSets/example")
df2
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df = pd.read_csv("C:/Users/Dell/Desktop/DataScince/Pandas/DataSets/appdata10.csv")
df
# Out:
#          user               first_open  dayofweek       hour  age  \
# 0      235136  2012-12-27 02:14:51.273          3   02:00:00   23
# 1      333588  2012-12-02 01:16:00.905          6   01:00:00   24
# 2      254414  2013-03-19 19:19:09.157          1   19:00:00   23
# 3      234192  2013-07-05 16:08:46.354          4   16:00:00   28
# 4       51549  2013-02-26 18:50:48.661          1   18:00:00   31
# ...       ...                      ...        ...        ...  ...
# 49995  222774  2013-05-09 13:46:17.871          3   13:00:00   32
# 49996  169179  2013-04-09 00:05:17.823          1   00:00:00   35
# 49997  302367  2013-02-20 22:41:51.165          2   22:00:00   39
# 49998  324905  2013-04-28 12:33:04.288          6   12:00:00   27
# 49999   27047  2012-12-14 01:22:44.638          4   01:00:00   25
#
#                                              screen_list  numscreens  \
# 0      idscreen,joinscreen,Cycle,product_review,ScanP...          15
# ...

# %%
df.head()
# Out:
#      user               first_open  dayofweek       hour  age  \
# 0  235136  2012-12-27 02:14:51.273          3   02:00:00   23
# 1  333588  2012-12-02 01:16:00.905          6   01:00:00   24
# 2  254414  2013-03-19 19:19:09.157          1   19:00:00   23
# 3  234192  2013-07-05 16:08:46.354          4   16:00:00   28
# 4   51549  2013-02-26 18:50:48.661          1   18:00:00   31
#
#                                          screen_list  numscreens  minigame  \
# 0  idscreen,joinscreen,Cycle,product_review,ScanP...          15         0
# 1  joinscreen,product_review,product_review2,Scan...          13         0
# 2                                  Splash,Cycle,Loan           3         0
# 3  product_review,Home,product_review,Loan3,Finan...          40         0
# 4  idscreen,joinscreen,Cycle,Credit3Container,Sca...          32         0
#
#    used_premium_feature  enrolled            enrolled_date  liked
# 0                     0         0                      NaN      0
# ...

# %%
df.tail()
# Out:
#          user               first_open  dayofweek       hour  age  \
# 49995  222774  2013-05-09 13:46:17.871          3   13:00:00   32
# 49996  169179  2013-04-09 00:05:17.823          1   00:00:00   35
# 49997  302367  2013-02-20 22:41:51.165          2   22:00:00   39
# 49998  324905  2013-04-28 12:33:04.288          6   12:00:00   27
# 49999   27047  2012-12-14 01:22:44.638          4   01:00:00   25
#
#                                              screen_list  numscreens  \
# 49995  Splash,Home,ScanPreview,VerifyPhone,VerifySSN,...          13
# 49996                 Cycle,Splash,Home,RewardsContainer           4
# 49997  joinscreen,product_review,product_review2,Scan...          25
# 49998  Cycle,Home,product_review,product_review,produ...          26
# 49999  product_review,ScanPreview,VerifyDateOfBirth,V...          26
#
#        minigame  used_premium_feature  enrolled            enrolled_date  \
# 49995         0                     0         1  2013-05-09 13:47:52.875
# ...

# %%
df.head(20)
# Out:
#       user               first_open  dayofweek       hour  age  \
# 0   235136  2012-12-27 02:14:51.273          3   02:00:00   23
# 1   333588  2012-12-02 01:16:00.905          6   01:00:00   24
# 2   254414  2013-03-19 19:19:09.157          1   19:00:00   23
# 3   234192  2013-07-05 16:08:46.354          4   16:00:00   28
# 4    51549  2013-02-26 18:50:48.661          1   18:00:00   31
# 5    56480  2013-04-03 09:58:15.752          2   09:00:00   20
# 6   144649  2012-12-25 02:33:18.461          1   02:00:00   35
# 7   249366  2012-12-11 03:07:49.875          1   03:00:00   26
# 8   372004  2013-03-20 14:22:01.569          2   14:00:00   29
# 9   338013  2013-04-26 18:22:16.013          4   18:00:00   26
# 10   43555  2013-05-14 04:48:27.597          1   04:00:00   39
# 11  317454  2013-05-28 11:07:07.358          1   11:00:00   32
# 12  205375  2012-12-17 06:28:45.903          0   06:00:00   25
# 13  307608  2013-05-25 19:52:31.798          5   19:00:00   23
# ...

# %%
df.tail(20)
# Out:
#          user               first_open  dayofweek       hour  age  \
# 49980   66561  2013-05-21 07:10:44.095          1   07:00:00   35
# 49981   15782  2013-05-15 04:01:16.993          2   04:00:00   28
# 49982  352052  2013-01-04 02:24:36.509          4   02:00:00   58
# 49983  325275  2013-04-15 13:41:11.079          0   13:00:00   28
# 49984   27126  2013-03-18 16:34:39.122          0   16:00:00   46
# 49985  150486  2013-07-05 23:19:47.630          4   23:00:00   24
# 49986   89415  2013-01-21 18:16:17.842          0   18:00:00   21
# 49987  255265  2013-06-17 19:27:27.910          0   19:00:00   25
# 49988  286847  2013-01-20 02:49:41.102          6   02:00:00   48
# 49989   31525  2013-04-12 17:34:40.117          4   17:00:00   27
# 49990  179308  2013-05-25 17:30:47.675          5   17:00:00   20
# 49991   85532  2013-02-01 22:33:59.502          4   22:00:00   45
# 49992   96155  2013-02-03 15:41:52.059          6   15:00:00   50
# ...

# %%
df.columns
# Out:
# Index(['user', 'first_open', 'dayofweek', 'hour', 'age', 'screen_list',
#        'numscreens', 'minigame', 'used_premium_feature', 'enrolled',
#        'enrolled_date', 'liked'],
#       dtype='object')

# %%
df['user']
# Out:
# 0        235136
# 1        333588
# 2        254414
# 3        234192
# 4         51549
#           ...
# 49995    222774
# 49996    169179
# 49997    302367
# 49998    324905
# 49999     27047
# Name: user, Length: 50000, dtype: int64

# %%
df[['user','hour','liked']]
# Out:
#          user       hour  liked
# 0      235136   02:00:00      0
# 1      333588   01:00:00      0
# 2      254414   19:00:00      1
# 3      234192   16:00:00      0
# 4       51549   18:00:00      1
# ...       ...        ...    ...
# 49995  222774   13:00:00      0
# 49996  169179   00:00:00      0
# 49997  302367   22:00:00      0
# 49998  324905   12:00:00      0
# 49999   27047   01:00:00      1
#
# [50000 rows x 3 columns]

# %%
df['age'].max()
# Out:
# 101

# %%
df['age'].min()
# Out:
# 16

# %%
df['age'].mean()
# Out:
# 31.72436

# %%
df['age']
# Out:
# 0        23
# 1        24
# 2        23
# 3        28
# 4        31
#          ..
# 49995    32
# 49996    35
# 49997    39
# 49998    27
# 49999    25
# Name: age, Length: 50000, dtype: int64

# %%
df.user  #Sql syntax, it will fetch the data but not recommended.
# Out:
# 0        235136
# 1        333588
# 2        254414
# 3        234192
# 4         51549
#           ...
# 49995    222774
# 49996    169179
# 49997    302367
# 49998    324905
# 49999     27047
# Name: user, Length: 50000, dtype: int64

# %%
df["user"][df["age"] == 50]
# Out:
# 222      324080
# 309      251478
# 326       73851
# 335      281508
# 357       60228
#           ...
# 49349     82302
# 49429    331440
# 49578    211143
# 49700    112414
# 49992     96155
# Name: user, Length: 424, dtype: int64

# %%
df["user"][df["age"] == 50].count()
# Out:
# 424

# %%
df["user"][df["liked"] == 1]
# Out:
# 2        254414
# 4         51549
# 18       257945
# 23       200187
# 31       198725
#           ...
# 49981     15782
# 49983    325275
# 49990    179308
# 49993    343026
# 49999     27047
# Name: user, Length: 8250, dtype: int64

# %%
df["user"][df["liked"] == 0]
# Out:
# 0        235136
# 1        333588
# 3        234192
# 5         56480
# 6        144649
#           ...
# 49994     90813
# 49995    222774
# 49996    169179
# 49997    302367
# 49998    324905
# Name: user, Length: 41750, dtype: int64

# %%
df["user"][df["liked"] == 1].count()
# Out:
# 8250

# %%
df["user"][df["liked"] == 0].count()
# Out:
# 41750

# %%
df["age"].describe()
# Out:
# count    50000.00000
# mean        31.72436
# std         10.80331
# min         16.00000
# 25%         24.00000
# 50%         29.00000
# 75%         37.00000
# max        101.00000
# Name: age, dtype: float64
